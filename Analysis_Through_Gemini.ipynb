# %% [markdown]
# <a href="https://colab.research.google.com/github/SaranshOp/BTP/blob/main/Analysis_Through_Gemini.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Working Environment

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Gemini_Hands_On/
# !ls
# Out:
# /content/drive/MyDrive/Gemini_Hands_On
# Reviews_handson.tsv

# %% [markdown]
# ### Import Dataset

# %%
import pandas as pd

data = pd.read_csv('Reviews_handson.tsv', sep='\t')
data.head(10)
# Out:
#    rating       date             variation  \
# 0       5  31-Jul-18      Charcoal Fabric
# 1       5  31-Jul-18      Charcoal Fabric
# 2       4  31-Jul-18        Walnut Finish
# 3       5  31-Jul-18      Charcoal Fabric
# 4       5  31-Jul-18      Charcoal Fabric
# 5       5  31-Jul-18  Heather Gray Fabric
# 6       3  31-Jul-18     Sandstone Fabric
# 7       5  31-Jul-18      Charcoal Fabric
# 8       5  30-Jul-18  Heather Gray Fabric
# 9       5  30-Jul-18  Heather Gray Fabric
#
#                                     verified_reviews  feedback
# 0                                      Love my Echo!         1
# 1                                          Loved it!         1
# 2  Sometimes while playing a game, you can answer...         1
# 3  I have had a lot of fun with this thing. My 4 ...         1
# 4                                              Music         1
# 5  I received the echo as a gift. I needed anothe...         1
# 6  Without having a cellphone, I cannot use many ...         1
# 7  I think this is the 5th one I've purchased. I'...         1
# 8                                        looks great         1
# 9  Love it! I’ve listened to songs I haven’t hear...         1

# %%
mydata = data[['verified_reviews','feedback']]
mydata.columns = ['review','label']

mydata.head()
# Out:
#                                               review  label
# 0                                      Love my Echo!      1
# 1                                          Loved it!      1
# 2  Sometimes while playing a game, you can answer...      1
# 3  I have had a lot of fun with this thing. My 4 ...      1
# 4                                              Music      1

# %%
mydata.value_counts('label')
# Out:
# label
# 1    2893
# 0     257
# Name: count, dtype: int64

# %%
# Count the occurrences of labels
label_counts = mydata["label"].value_counts()

# majority class
rows_to_drop = label_counts.max() - label_counts.min()

# Drop rows from the majority class randomly
if rows_to_drop > 0:
   data_majority = mydata[mydata["label"] == 1]
   data_balanced = mydata.drop(data_majority.sample(rows_to_drop).index)
else:
   data_balanced = mydata.copy()

print(data_balanced["label"].value_counts())
# Out:
# label
# 1    257
# 0    257
# Name: count, dtype: int64

# %% [markdown]
# ## Data Preprocessing

# %%
import re

def clean_text(text):
  # Remove special characters and punctuation
  text = re.sub(r"[^\w\s]", " ", text)

  # Remove single characters
  text = re.sub(r"\b[a-zA-Z]\b", " ", text)

  # Remove HTML tags
  text = re.sub(r"<[^>]*>", " ", text)

  # Lowercase the text
  text = text.lower()

  # Remove extra whitespace
  text = re.sub(r"\s+", " ", text)

  # Trim leading and trailing spaces
  text = text.strip()

  return text

# %%
import pandas as pd

reviews = data_balanced['review'].tolist()

# %%
data_balanced.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 514 entries, 0 to 3142
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   review  513 non-null    object
#  1   label   514 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 12.0+ KB

# %%
len(reviews)
# Out:
# 514

# %%
cleaned_reviews = []

for review in reviews:
    if isinstance(review, str):
        cleaned_review = clean_text(review)
        cleaned_reviews.append(cleaned_review)
    else:
        cleaned_reviews.append(" ")
        pass
len(cleaned_review)
# Out:
# 110

# %%
data_balanced['clean_reviews'] = cleaned_reviews
data_balanced
# Out:
#                                                  review  label  \
# 0                                         Love my Echo!      1
# 18    We love the size of the 2nd generation echo. S...      1
# 24    I got a second unit for the bedroom, I was exp...      1
# 31                                            I like it      1
# 36    Love my Echo. Still learning all the things it...      1
# ...                                                 ...    ...
# 3096  The product sounded the same as the emoji spea...      0
# 3109  Easy to set up and connect with smart devices....      1
# 3115  It is just not as loud as I thought it was goi...      1
# 3138  Este producto llegó y a la semana se quedó sin...      1
# 3142  My three year old loves it.  Good for doing ba...      1
#
#                                           clean_reviews
# 0                                          love my echo
# 18    we love the size of the 2nd generation echo st...
# 24    got second unit for the bedroom was expecting ...
# 31                                              like it
# 36    love my echo still learning all the things it ...
# ...                                                 ...
# 3096  the product sounded the same as the emoji spea...
# 3109  easy to set up and connect with smart devices ...
# 3115  it is just not as loud as thought it was going...
# 3138  este producto llegó la semana se quedó sin olo...
# 3142  my three year old loves it good for doing basi...
#
# [514 rows x 3 columns]

# %% [markdown]
# ## Data Split

# %%
import pandas as pd

total_rows = len(data_balanced)
test_size = int(total_rows * 0.95)

test_set = data_balanced.sample(test_size)

train_set = data_balanced.drop(test_set.index)

# %% [markdown]
# ## Sentiment w/ LLM

# %% [markdown]
# ### Setting up Gemini API

# %%
# !pip install -q -U google-generativeai

# %%
# Necessary packages
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown


def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# Used to securely store your API key
from google.colab import userdata

# %%
# Or use `os.getenv('GOOGLE_API_KEY')` to fetch an environment variable.
GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')

genai.configure(api_key=GOOGLE_API_KEY)

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-1.5-pro-latest
# models/gemini-pro
# models/gemini-pro-vision

# %%
model = genai.GenerativeModel('gemini-pro')

# %%
# %%time
response = model.generate_content("What is the meaning of life?")

to_markdown(response.text)
# Out:
# CPU times: user 128 ms, sys: 14 ms, total: 142 ms
# Wall time: 10.5 s
# > **Existential and Philosophical Perspectives:**
# >
# > * **Absolutism:** Life has an inherent, objective meaning that exists independently of human interpretation.
# > * **Existentialism:** Life has no inherent meaning, and individuals must create their own.
# > * **Nihilism:** Life is meaningless and devoid of purpose.
# > * **Hedonism:** The meaning of life lies in the pursuit of pleasure and the avoidance of pain.
# > * **Utilitarianism:** The purpose of life is to maximize happiness and well-being.
# > * **Stoicism:** Life is a series of challenges and obstacles that should be met with equanimity and acceptance.
# >
# > **Religious and Spiritual Beliefs:**
# >
# > * **Theism:** Life has a divinely ordained purpose, such as serving God or experiencing spiritual growth.
# > * **Humanism:** The meaning of life lies in the cultivation of human values and the pursuit of a fulfilling life.
# > * **Buddhism:** Life is characterized by suffering and impermanence, and the meaning lies in breaking the cycle of rebirth through enlightenment.
# > * **Hinduism:** Life is part of a continuous cycle of birth, death, and rebirth, with the ultimate goal of attaining moksha (liberation).
# >
# > **Psychological and Developmental Theories:**
# >
# > * **Maslow's Hierarchy of Needs:** The meaning of life involves meeting basic needs (e.g., food, safety) and pursuing higher-order needs (e.g., self-actualization).
# > * **Erikson's Stages of Life:** Life progresses through a series of developmental stages, each with its own unique purpose.
# > * **Positive Psychology:** The meaning of life lies in experiencing positive emotions, having meaningful relationships, and engaging in purposeful activities.
# >
# > **Personal Experiences and Interpretations:**
# >
# > * **Purpose:** Finding a sense of purpose or direction in life can provide meaning.
# > * **Relationships:** Building strong and fulfilling relationships with others can enrich life.
# > * **Creativity and Expression:** Expressing oneself through creativity or other forms of self-expression can give life meaning.
# > * **Service and Altruism:** Helping others and making a positive impact on the world can provide a sense of fulfillment.
# > * **Legacy:** Leaving a lasting legacy through one's actions, ideas, or creations can give life purpose.
# >
# > Ultimately, the meaning of life is a highly subjective and personal concept that varies greatly depending on individual beliefs, values, and experiences.

# %% [markdown]
# #### Single API Call

# %%
test_set_sample = test_set.sample(20)

test_set_sample['pred_label'] = ''

test_set_sample
# Out:
#                                                  review  label  \
# 444                   Very puny sound, but works great.      1
# 1378                                    Fairly useless.      0
# 424   Great product but returning for new Alexa Dot....      0
# 551   product stopped working after return time ran out      0
# 871                                Sad joke. Worthless.      0
# 434   &#34;NEVER BUY CERTIFIED AND REFURBISHED ECHO ...      0
# 406                                                          0
# 1291  item returned for repair ,receivded item back ...      0
# 1764                                                         0
# 2558  For the price, the product is nice quality and...      0
# 2013  I bought this for myself and i didn’t realize ...      0
# 177                                       Entertainment      1
# 2894  Some times Alexa is a little &#34;thick&#34;, ...      1
# 521   Two weeks after setting it up it no longer wor...      0
# 2297  Great product. Love the larger remote! Great d...      1
# 1105                                    So far so good.      1
# 2603  I really like the echo dot. It’s amazing to be...      1
# 2330  It's constantly buffering, to the point where ...      0
# 632         Great little thing. Works better than siri.      1
# 141                                  Not much features.      0
#
#                                           clean_reviews pred_label
# 444                     very puny sound but works great
# 1378                                     fairly useless
# 424   great product but returning for new alexa dot ...
# 551   product stopped working after return time ran out
# 871                                  sad joke worthless
# 434   34 never buy certified and refurbished echo do...
# 406
# 1291  item returned for repair receivded item back f...
# 1764
# 2558  for the price the product is nice quality and ...
# 2013  bought this for myself and didn realize it had...
# 177                                       entertainment
# 2894  some times alexa is little 34 thick 34 but mos...
# 521   two weeks after setting it up it no longer wor...
# 2297    great product love the larger remote great deal
# 1105                                     so far so good
# 2603  really like the echo dot it amazing to be able...
# 2330  it constantly buffering to the point where you...
# 632           great little thing works better than siri
# 141                                   not much features

# %%
# Convert the DataFrame to JSON

json_data = test_set_sample[['clean_reviews','pred_label']].to_json(orient='records')

print(json_data)
# Out:
# [{"clean_reviews":"very puny sound but works great","pred_label":""},{"clean_reviews":"fairly useless","pred_label":""},{"clean_reviews":"great product but returning for new alexa dot refurbished is already giving me problems with connection","pred_label":""},{"clean_reviews":"product stopped working after return time ran out","pred_label":""},{"clean_reviews":"sad joke worthless","pred_label":""},{"clean_reviews":"34 never buy certified and refurbished echo dot 34 bought 34 certified and refurbished 34 echo dot this unit is very poor in receiving command and sometimes it does not even acknowledge the command never buy refurbished echo dot the unit received was probably never was certified and refurbished as indicated also bought new echo dot it works perfectly very disappointed","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"item returned for repair receivded item back from repair 07 23 18 parts missing no power cord included please advise","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"for the price the product is nice quality and has few nice features so definitely no complaints there the reason why only gave it 3 stars is because the echo dot is not what thought it was going to be so that may just be buyer error first didn know that the product has to be plugged in at all times to work so really don like that it not stand alone device also the speaker is not very loud so if you are buying it as bluetooth speaker don lastly sure the echo dot can do lot but haven quite figured out how to use it fully but it just kind of seems like an unnecessary device to own plus setting it up was awful would definitely save the money and buy the nicer one that is actually alexa","pred_label":""},{"clean_reviews":"bought this for myself and didn realize it had to be plugged in just to work it isn convenient to make them always have to connect to wall it should ve been more clear when bought it","pred_label":""},{"clean_reviews":"entertainment","pred_label":""},{"clean_reviews":"some times alexa is little 34 thick 34 but mostly good","pred_label":""},{"clean_reviews":"two weeks after setting it up it no longer works no connection no light no sound guess shouldn have purchased refurbished dot","pred_label":""},{"clean_reviews":"great product love the larger remote great deal","pred_label":""},{"clean_reviews":"so far so good","pred_label":""},{"clean_reviews":"really like the echo dot it amazing to be able to set an alarm or timer just by talking to the echo dot","pred_label":""},{"clean_reviews":"it constantly buffering to the point where you can watch anything without interruption purchased on prime day plus used rewards to pay for it so in the end paid next to nothing if had paid full price for it might want my money back we stopped trying to use it and went back to our old streaming device know our internet service is not the issue because we do not have this problem with any other devices that we stream from","pred_label":""},{"clean_reviews":"great little thing works better than siri","pred_label":""},{"clean_reviews":"not much features","pred_label":""}]

# %%
prompt = f"""
You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
Customer reviews are provided between three back ticks.
In your output, only return the Json code back as output - which is provided between three backticks.
Your task is to update predicted labels under 'pred_label' in the Json code.
Don't make any changes to Json code format, please.

```
{json_data}
```
"""

print(prompt)
# Out:
# You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
# Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
# Customer reviews are provided between three back ticks.
# In your output, only return the Json code back as output - which is provided between three backticks.
# Your task is to update predicted labels under 'pred_label' in the Json code.
# Don't make any changes to Json code format, please.
#
# ```
# [{"clean_reviews":"very puny sound but works great","pred_label":""},{"clean_reviews":"fairly useless","pred_label":""},{"clean_reviews":"great product but returning for new alexa dot refurbished is already giving me problems with connection","pred_label":""},{"clean_reviews":"product stopped working after return time ran out","pred_label":""},{"clean_reviews":"sad joke worthless","pred_label":""},{"clean_reviews":"34 never buy certified and refurbished echo dot 34 bought 34 certified and refurbished 34 echo dot this unit is very poor in receiving command and sometimes it does not even acknowledge the command never buy refurbished echo dot the unit received was probably never was certified and refurbished as indicated also bought new echo dot it works perfectly very disappointed","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"item returned for repair receivded item back from repair 07 23 18 parts missing no power cord included please advise","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"for the price the product is nice quality and has few nice features so definitely no complaints there the reason why only gave it 3 stars is because the echo dot is not what thought it was going to be so that may just be buyer error first didn know that the product has to be plugged in at all times to work so really don like that it not stand alone device also the speaker is not very loud so if you are buying it as bluetooth speaker don lastly sure the echo dot can do lot but haven quite figured out how to use it fully but it just kind of seems like an unnecessary device to own plus setting it up was awful would definitely save the money and buy the nicer one that is actually alexa","pred_label":""},{"clean_reviews":"bought this for myself and didn realize it had to be plugged in just to work it isn convenient to make them always have to connect to wall it should ve been more clear when bought it","pred_label":""},{"clean_reviews":"entertainment","pred_label":""},{"clean_reviews":"some times alexa is little 34 thick 34 but mostly good","pred_label":""},{"clean_reviews":"two weeks after setting it up it no longer works no connection no light no sound guess shouldn have purchased refurbished dot","pred_label":""},{"clean_reviews":"great product love the larger remote great deal","pred_label":""},{"clean_reviews":"so far so good","pred_label":""},{"clean_reviews":"really like the echo dot it amazing to be able to set an alarm or timer just by talking to the echo dot","pred_label":""},{"clean_reviews":"it constantly buffering to the point where you can watch anything without interruption purchased on prime day plus used rewards to pay for it so in the end paid next to nothing if had paid full price for it might want my money back we stopped trying to use it and went back to our old streaming device know our internet service is not the issue because we do not have this problem with any other devices that we stream from","pred_label":""},{"clean_reviews":"great little thing works better than siri","pred_label":""},{"clean_reviews":"not much features","pred_label":""}]
# ```

# %%
response = model.generate_content(prompt)

print(response.text)
# Out:
# ```
# [{"clean_reviews":"very puny sound but works great","pred_label":1},{"clean_reviews":"fairly useless","pred_label":0},{"clean_reviews":"great product but returning for new alexa dot refurbished is already giving me problems with connection","pred_label":0},{"clean_reviews":"product stopped working after return time ran out","pred_label":0},{"clean_reviews":"sad joke worthless","pred_label":0},{"clean_reviews":"34 never buy certified and refurbished echo dot 34 bought 34 certified and refurbished 34 echo dot this unit is very poor in receiving command and sometimes it does not even acknowledge the command never buy refurbished echo dot the unit received was probably never was certified and refurbished as indicated also bought new echo dot it works perfectly very disappointed","pred_label":0},{"clean_reviews":"","pred_label":0},{"clean_reviews":"item returned for repair receivded item back from repair 07 23 18 parts missing no power cord included please advise","pred_label":0},{"clean_reviews":"","pred_label":0},{"clean_reviews":"for the price the product is nice quality and has few nice features so definitely no complaints there the reason why only gave it 3 stars is because the echo dot is not what thought it was going to be so that may just be buyer error first didn know that the product has to be plugged in at all times to work so really don like that it not stand alone device also the speaker is not very loud so if you are buying it as bluetooth speaker don lastly sure the echo dot can do lot but haven quite figured out how to use it fully but it just kind of seems like an unnecessary device to own plus setting it up was awful would definitely save the money and buy the nicer one that is actually alexa","pred_label":0},{"clean_reviews":"bought this for myself and didn realize it had to be plugged in just to work it isn convenient to make them always have to connect to wall it should ve been more clear when bought it","pred_label":0},{"clean_reviews":"entertainment","pred_label":1},{"clean_reviews":"some times alexa is little 34 thick 34 but mostly good","pred_label":1},{"clean_reviews":"two weeks after setting it up it no longer works no connection no light no sound guess shouldn have purchased refurbished dot","pred_label":0},{"clean_reviews":"great product love the larger remote great deal","pred_label":1},{"clean_reviews":"so far so good","pred_label":1},{"clean_reviews":"really like the echo dot it amazing to be able to set an alarm or timer just by talking to the echo dot","pred_label":1},{"clean_reviews":"it constantly buffering to the point where you can watch anything without interruption purchased on prime day plus used rewards to pay for it so in the end paid next to nothing if had paid full price for it might want my money back we stopped trying to use it and went back to our old streaming device know our internet service is not the issue because we do not have this problem with any other devices that we stream from","pred_label":0},{"clean_reviews":"great little thing works better than siri","pred_label":1},{"clean_reviews":"not much features","pred_label":0}]
# ```

# %%
import json

# stripping the backticks
json_data = response.text.strip("`")

# Load the cleaned data
data = json.loads(json_data)
df_sample = pd.DataFrame(data)

df_sample
# Out:
#                                         clean_reviews  pred_label
# 0                     very puny sound but works great           1
# 1                                      fairly useless           0
# 2   great product but returning for new alexa dot ...           0
# 3   product stopped working after return time ran out           0
# 4                                  sad joke worthless           0
# 5   34 never buy certified and refurbished echo do...           0
# 6                                                               0
# 7   item returned for repair receivded item back f...           0
# 8                                                               0
# 9   for the price the product is nice quality and ...           0
# 10  bought this for myself and didn realize it had...           0
# 11                                      entertainment           1
# 12  some times alexa is little 34 thick 34 but mos...           1
# 13  two weeks after setting it up it no longer wor...           0
# 14    great product love the larger remote great deal           1
# 15                                     so far so good           1
# 16  really like the echo dot it amazing to be able...           1
# 17  it constantly buffering to the point where you...           0
# 18          great little thing works better than siri           1
# 19                                  not much features           0

# %%
# prompt: Overwrite pred_label from 'df' to in 'train_set_sample'

test_set_sample['pred_label'] = df_sample['pred_label'].values
test_set_sample
# Out:
#                                                  review  label  \
# 444                   Very puny sound, but works great.      1
# 1378                                    Fairly useless.      0
# 424   Great product but returning for new Alexa Dot....      0
# 551   product stopped working after return time ran out      0
# 871                                Sad joke. Worthless.      0
# 434   &#34;NEVER BUY CERTIFIED AND REFURBISHED ECHO ...      0
# 406                                                          0
# 1291  item returned for repair ,receivded item back ...      0
# 1764                                                         0
# 2558  For the price, the product is nice quality and...      0
# 2013  I bought this for myself and i didn’t realize ...      0
# 177                                       Entertainment      1
# 2894  Some times Alexa is a little &#34;thick&#34;, ...      1
# 521   Two weeks after setting it up it no longer wor...      0
# 2297  Great product. Love the larger remote! Great d...      1
# 1105                                    So far so good.      1
# 2603  I really like the echo dot. It’s amazing to be...      1
# 2330  It's constantly buffering, to the point where ...      0
# 632         Great little thing. Works better than siri.      1
# 141                                  Not much features.      0
#
#                                           clean_reviews  pred_label
# 444                     very puny sound but works great           1
# 1378                                     fairly useless           0
# 424   great product but returning for new alexa dot ...           0
# 551   product stopped working after return time ran out           0
# 871                                  sad joke worthless           0
# 434   34 never buy certified and refurbished echo do...           0
# 406                                                               0
# 1291  item returned for repair receivded item back f...           0
# 1764                                                              0
# 2558  for the price the product is nice quality and ...           0
# 2013  bought this for myself and didn realize it had...           0
# 177                                       entertainment           1
# 2894  some times alexa is little 34 thick 34 but mos...           1
# 521   two weeks after setting it up it no longer wor...           0
# 2297    great product love the larger remote great deal           1
# 1105                                     so far so good           1
# 2603  really like the echo dot it amazing to be able...           1
# 2330  it constantly buffering to the point where you...           0
# 632           great little thing works better than siri           1
# 141                                   not much features           0

# %%
# EVAL

from sklearn.metrics import confusion_matrix

y_true = test_set_sample["label"]
y_pred = test_set_sample["pred_label"]

confusion_matrix(y_true, y_pred)
# Out:
# array([[13,  0],
#        [ 0,  7]])

# %% [markdown]
# ### Batching API Calls: Gemini API

# %%
test_set.shape
# Out:
# (488, 3)

# %%
test_set_total = test_set.sample(100)

test_set_total['pred_label'] = ''

test_set_total
# Out:
#                                                  review  label  \
# 1549                   Very intrusive, so I turn it off      0
# 1036                             Alexa hardly came on..      0
# 2706  Great to play music throughout the house. Grea...      1
# 1311  LOVE love love this!  I have an echo, and seve...      1
# 2390  I would not recommend this to anyone. It won't...      0
# ...                                                 ...    ...
# 2621                                            Love it      1
# 618                             Extremely low in volume      0
# 1628  Echo Show is perfect for staging in the kitche...      1
# 1013  My  wife & I enjoy the ease of playing our mus...      1
# 3138  Este producto llegó y a la semana se quedó sin...      1
#
#                                           clean_reviews pred_label
# 1549                      very intrusive so turn it off
# 1036                               alexa hardly came on
# 2706  great to play music throughout the house great...
# 1311  love love love this have an echo and several e...
# 2390  would not recommend this to anyone it won load...
# ...                                                 ...        ...
# 2621                                            love it
# 618                             extremely low in volume
# 1628  echo show is perfect for staging in the kitche...
# 1013  my wife enjoy the ease of playing our music th...
# 3138  este producto llegó la semana se quedó sin olo...
#
# [100 rows x 4 columns]

# %%
batches = []
batch_size = 25

for i in range(0, len(test_set_total), batch_size):
  batches.append(test_set_total[i : i + batch_size])

# %%
import time

def gemini_completion_function(batch,current_batch,total_batch):
  """Function works in three steps:
  # Step-1: Convert the DataFrame to JSON using the to_json() method.
  # Step-2: Preparing the Gemini Prompt
  # Step-3: Calling Gemini API
  """

  print(f"Now processing batch#: {current_batch+1} of {total_batch}")

  json_data = batch[['clean_reviews','pred_label']].to_json(orient='records')

  prompt = f"""You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
  Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
  Customer reviews are provided between three backticks below.
  In your output, only return the Json code back as output - which is provided between three backticks.
  Your task is to update predicted labels under 'pred_label' in the Json code.
  Don't make any changes to Json code format, please.
  Error handling instruction: In case a Customer Review violates API policy, please assign it default sentiment as Negative (label=0).

  ```
  {json_data}
  ```
  """

  print(prompt)
  response = model.generate_content(prompt)
  time.sleep(5)

  return response

# %%
batch_count = len(batches)
responses = []

for i in range(0,len(batches)):
  responses.append(gemini_completion_function(batches[i],i,batch_count))
# Out:
# Now processing batch#: 1 of 4
# You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
#   Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
#   Customer reviews are provided between three backticks below.
#   In your output, only return the Json code back as output - which is provided between three backticks.
#   Your task is to update predicted labels under 'pred_label' in the Json code.
#   Don't make any changes to Json code format, please.
#   Error handling instruction: In case a Customer Review violates API policy, please assign it default sentiment as Negative (label=0).
#
#   ```
#   [{"clean_reviews":"very intrusive so turn it off","pred_label":""},{"clean_reviews":"alexa hardly came on","pred_label":""},{"clean_reviews":"great to play music throughout the house great and easily fits in my decor of my home","pred_label":""},{"clean_reviews":"love love love this have an echo and several echo dots but love the video with this and the clock no longer have to wake up and say 34 alexa what time is it 34 or 34 alexa weather 34 can even watch videos on it if forget my kindle before bed","pred_label":""},{"clean_reviews":"would not recommend this to anyone it won load netflix or if it does on rare occasion it won run the program all the way thru it tells you the we are unable to process this title at this time try again later it is not the netflix site cause can stream it just fine on my computer its the firestick very disappointing","pred_label":""},{"clean_reviews":"seems to be good product but unable to play music in sync with my sonos system sonos doesn seem to recognize it at all","pred_label":""},{"clean_reviews":"alexa us funny and enjoyable nice sound","pred_label":""},{"clean_reviews":"las pel\u00edculas no tiene no se pueden cambiar espa\u00f1ol t\u00edtulos en espa\u00f1ol","pred_label":""},{"clean_reviews":"love to watch my wife argue with alexa woke up one night listening to alexa talking to my cell phone","pred_label":""},{"clean_reviews":"love it","pred_label":""},{"clean_reviews":"not all that happy the speaker isn great and for some reason lot of times when play music it will start to make some weird noise and just stop my son has google home and it is much better","pred_label":""},{"clean_reviews":"bought for my bathroom to listen when in the shower love it","pred_label":""},{"clean_reviews":"product forces user to review alexa things to try there is no way to disable it","pred_label":""},{"clean_reviews":"the setup of this device was simple and effective am very pleased to see all of the additional skills and add on abilities of alexa this is great for my mobility issues now have the ability to have my shopping and comfort needs met without depending on friends and family","pred_label":""},{"clean_reviews":"was loving it but starting in june hulu stopped working and crunchyroll doesn work either probably will switch to something else soon","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"item returned for repair receivded item back from repair 07 23 18 parts missing no power cord included please advise","pred_label":""},{"clean_reviews":"we are really enjoying the echo plus it is fun too","pred_label":""},{"clean_reviews":"alexa is pretty dumb","pred_label":""},{"clean_reviews":"it like having another kid in the house have to constantly repeat myself can tell alexa to do something clear as day and according to the history she hears something comeletely different the device is really cool and like the concept which is why it gets two stars however it just doesn work as intended find myself irritated more often than not when use this device","pred_label":""},{"clean_reviews":"fairly useless","pred_label":""},{"clean_reviews":"the speaker is of surprising quality happy with the purchase","pred_label":""},{"clean_reviews":"reached out to amazon because the device wanted to sync my phone number but it would not allow because it said my number was already in use customer service couldn help they basically told me to contact sprint to assist so echo does the bare minimum without access to my phone for set up so its kind of pointless to have and pay for","pred_label":""},{"clean_reviews":"great product we listen to music all the time","pred_label":""},{"clean_reviews":"alexa is awesome the first day got my echo plus found out things that she can do that didn think were even possible highly recommend this product along with all the accessories","pred_label":""}]
#   ```
#
# Now processing batch#: 2 of 4
# You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
#   Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
#   Customer reviews are provided between three backticks below.
#   In your output, only return the Json code back as output - which is provided between three backticks.
#   Your task is to update predicted labels under 'pred_label' in the Json code.
#   Don't make any changes to Json code format, please.
#   Error handling instruction: In case a Customer Review violates API policy, please assign it default sentiment as Negative (label=0).
#
#   ```
#   [{"clean_reviews":"am not super impressed with alexa when my prime lapsed she wouldn play anything she isn smart enough to differentiate among spotify accounts so we can use it for that either she randomly speaks up when nobody is talking to her just today unplugged her not sure ll ever use my alexa again","pred_label":""},{"clean_reviews":"beyond my capabilities to program grandkids lve it","pred_label":""},{"clean_reviews":"good but it pretty low","pred_label":""},{"clean_reviews":"to have ability to play amazon music outside for patio gatherings also used blue tooth to connect echo plus via alexa app on my tablet to an external speaker when if the party extends into the yard have plans to connect other devices such as thermostat and other lighting and home devices","pred_label":""},{"clean_reviews":"at volume setting of half or less the speaker sounds like there is something rattling crackling or vibrating in it understand if the volume was set higher all speakers get distorted when over driven but this doesn sound like this is an over driven case sounds like more of rattle crackle possibly because the bass is too high learned that there is no ability to adjust any of the sound characteristics other than volume will attempt to exchange it assuming it is just an isolated problem","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"very bad this device don know if it because is refurbished or what but it activated by itself nobody is talking and he just activated and start talking when you talk you have to yell super lauded","pred_label":""},{"clean_reviews":"love my fire stick","pred_label":""},{"clean_reviews":"disconnects often","pred_label":""},{"clean_reviews":"waste of money over the echo generation 2 you don really get anything more from video chat on this device then you would on facetime or skype and it does not cycle through your pictures when you put it on slideshow mode it sticks on the first photo and will not leave it no matter what you do have even looked online to research articles and cannot find solution have also had problems with this device shutting down and have not had these problems on any of the other echo devices price difference is just not worth it","pred_label":""},{"clean_reviews":"doesn use apple music it is worthless to me without it sound quality on it is also poor","pred_label":""},{"clean_reviews":"not good at all","pred_label":""},{"clean_reviews":"got this on prime day and figured see what all the hype is about honestly didn really want to like it as personally bugging my house seems kinda weird but honestly love it like it or not this is the way the world is going so why not loved it so much ordered 2 didn get the show because it looks like it came from the 1990 and is downright ugly have no interest on watching anything on these devices anyway so the spot screen does not bother me although it is very clear alexa can hear you from pretty much everywhere my favorite part about this is having it in our living room where it hooked up to our bluetooth soundbar where can just say play any song want and it will guess could just pick up my smartphone to do that but you don know how much easier it is to interact with media using your voice rather than navigating through multiple pages the one thing that am not fan of is the home screen cards do not really rotate that much they also do not rotate when playing music love for it to display the weather as listen to music the screen is clear and also really enjoy alexa being able to tell me how my commute will be there is great skill that you can download that will tell you traffic to 5 different places that you program and name so you can say alexa give me traffic to my parents and she will tell you the best route and time you will arrive in current traffic have this programmed for my parents fiances parents work and her work so it really works great the one thing that actually preferred the dot over the spot is the dot will lig ...
#   ```
#
# Now processing batch#: 3 of 4
# You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
#   Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
#   Customer reviews are provided between three backticks below.
#   In your output, only return the Json code back as output - which is provided between three backticks.
#   Your task is to update predicted labels under 'pred_label' in the Json code.
#   Don't make any changes to Json code format, please.
#   Error handling instruction: In case a Customer Review violates API policy, please assign it default sentiment as Negative (label=0).
#
#   ```
#   [{"clean_reviews":"love alexa she works great but she not for little children she doesn understand if you don speak clearly she fun to have","pred_label":""},{"clean_reviews":"loved it till someone stoled it can afford to replace it yet but am going too","pred_label":""},{"clean_reviews":"simple install and love the voice activation","pred_label":""},{"clean_reviews":"great product love the larger remote great deal","pred_label":""},{"clean_reviews":"alarm calendar reminders","pred_label":""},{"clean_reviews":"alexa hardly came on","pred_label":""},{"clean_reviews":"works perfectly","pred_label":""},{"clean_reviews":"love the spot","pred_label":""},{"clean_reviews":"the echo works fine but then you get indundated with 34 things to try 34 am not 10 year old that needs stimulus to tell me to do things found there is no way to turn this off except for turning off the screen if cannot find suitable fix for this it goes back","pred_label":""},{"clean_reviews":"some times alexa is little 34 thick 34 but mostly good","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"am not super impressed with alexa when my prime lapsed she wouldn play anything she isn smart enough to differentiate among spotify accounts so we can use it for that either she randomly speaks up when nobody is talking to her just today unplugged her not sure ll ever use my alexa again","pred_label":""},{"clean_reviews":"it got great sound and bass but it doesn work all of the time its still hot or miss when it recognizes things","pred_label":""},{"clean_reviews":"bought the spot and loved it within months it started acting funny and would stop working called and they determined that it was overheating was told to unplug and technical support would call within 24 48 hours waited 48 hours without response and replied to email and was asked to wait week week goes by with absolutely no response so do the inline chat per instructions told to wait longer really unacceptable expected more from amazon find it funny how they always thank me for being prime member but when an issue arises cannot even get assistance","pred_label":""},{"clean_reviews":"works like charm fast delivery and no problems","pred_label":""},{"clean_reviews":"initially this echo dot worked very well over time the dot stopped responding to alexa unless you were within one foot of it yelling the other echos echo dots in other rooms would respond without response from this echo dot would not recommend buying refurbished","pred_label":""},{"clean_reviews":"love this product use it as my bedroom clock perfect size with lot of other options the only thing would like to see them add on to it is the ability to fall asleep to mu as if and set timer for it to go off on it own like you can with tv hcfe sleep mode","pred_label":""},{"clean_reviews":"it got great sound and bass but it doesn work all of the time its still hot or miss when it recognizes things","pred_label":""},{"clean_reviews":"thought it would be more powerful and have lot more functionality not much better than the echo dot not worth the money","pred_label":""},{"clean_reviews":"makes turning on and off things in the house so simple great for little updates as well like checking the weather and such","pred_label":""},{"clean_reviews":"was really happy with my original echo so thought get an echo dot to use in my bedroom was really disappointed in the audio quality so connected an external speaker via bluetooth the audio was much better but started having problems with it loosing connection with the wifi presumably due to interference from the bluetooth then connected speaker via the auxiliary jack when did that the auxiliary jack picked up interference from the wifi and was woken up in the middle of the night by horrible buzzing sound im hoping amazon will take this thing back and give me good deal on an echo spot which hope will be better nightstand device","pred_label":""},{"clean_reviews":"fun to interact with","pred_label":" ...
#   ```
#
# Now processing batch#: 4 of 4
# You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
#   Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
#   Customer reviews are provided between three backticks below.
#   In your output, only return the Json code back as output - which is provided between three backticks.
#   Your task is to update predicted labels under 'pred_label' in the Json code.
#   Don't make any changes to Json code format, please.
#   Error handling instruction: In case a Customer Review violates API policy, please assign it default sentiment as Negative (label=0).
#
#   ```
#   [{"clean_reviews":"as an alexa device it works just as well as any of the other products unfortunately it doesn go up from there the ability to play videos is very limited you can not play youtube and when you can play video the cropping of the screen makes it look very strange there is quite selection of clock faces and you can control what is displays with one glaring and very annoying exception you can turn off the 34 things to try 34 screen you can turn off the screen scroll but that defeats the purpose of having the screen don need to be reminded every 5 seconds what things can do with alexa don need the advertising especially at the cost of this device overall its an expensive alexa device with screen that not very useful and annoying would not recommend this until the amazon people get their act together and come up with screen that actually useful","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"as an echo its great good sound quality and functionality as smart home hub it sucks no automation no geo fencing no music syncing for hue no wave all it does is turn things on with your voice ended up buying smartthing hub and transferring everything over","pred_label":""},{"clean_reviews":"speaker sounds good","pred_label":""},{"clean_reviews":"am having real difficulty working with the echo dot alexi is not very smart 9 out of 10 questions have asked get the 34 not sure 34 half the time am still asking the question and alexi is saying 34 not sure 34 the music is great and works well for that all in all so far it been very frustrating experience","pred_label":""},{"clean_reviews":"awesome device","pred_label":""},{"clean_reviews":"just think that it to darn confusing and there are parts that would try and just wouldn work just don like it not what thought it would be","pred_label":""},{"clean_reviews":"34 never buy certified and refurbished echo dot 34 bought 34 certified and refurbished 34 echo dot this unit is very poor in receiving command and sometimes it does not even acknowledge the command never buy refurbished echo dot the unit received was probably never was certified and refurbished as indicated also bought new echo dot it works perfectly very disappointed","pred_label":""},{"clean_reviews":"works great some of the apps will start buffering but it probably my internet love the alexa voice control","pred_label":""},{"clean_reviews":"great sound","pred_label":""},{"clean_reviews":"got it and as expected its great almost swell as my show","pred_label":""},{"clean_reviews":"so far so good","pred_label":""},{"clean_reviews":"got this as gift so cool can view my news recipes or shopping lists and much more","pred_label":""},{"clean_reviews":"the thing like most about my echo spot is the voice command feature you can ask anything and get an answer or play any music without getting up to adjust the echo easy to use","pred_label":""},{"clean_reviews":"we have six of these throughout our home and they are great there are times when music or talking happens randomly that may be from sensitive listening there should be more options to change the name of the engagement command 34 alexa 34 or 34 computer 34 are little annoying more colors then black and white would also be good thing","pred_label":""},{"clean_reviews":"seems to work ok but no youtube tv really can believe they would ban an app that so many people want to use really wanted to like it but when couldn install that particular app it became almost useless almost does most other stuff just fine but ll stick with my roku","pred_label":""},{"clean_reviews":"fun to interact with","pred_label":""},{"clean_reviews":"it sucks","pred_label":""},{"clean_reviews":"wanted white dot for my white bathroom the top is black as shown which knew but did not realize the cord and plug were also black wanted white cord and plug","pred_label":""},{"clean_reviews":"have been thinking about getting this for long time and was excited when it arrived bundled with phi ...
#   ```

# %%
import json

df_total = pd.DataFrame()

for response in responses:
    # Stripping the backticks
    json_data = response.text.strip("`")

    # Load the cleaned data and convert to DataFrame
    data = json.loads(json_data)
    df_temp = pd.DataFrame(data)

    # Concatenate df_temp with df_total
    df_total = pd.concat([df_total, df_temp], ignore_index=True)

print(df_total)
# Out:
#                                         clean_reviews  pred_label
# 0                       very intrusive so turn it off           0
# 1                                alexa hardly came on           0
# 2   great to play music throughout the house great...           1
# 3   love love love this have an echo and several e...           1
# 4   would not recommend this to anyone it won load...           0
# ..                                                ...         ...
# 95                                            love it           1
# 96                            extremely low in volume           0
# 97  echo show is perfect for staging in the kitche...           1
# 98  my wife enjoy the ease of playing our music th...           1
# 99  este producto llegó la semana se quedó sin olo...           0
#
# [100 rows x 2 columns]

# %%
# prompt: Overwrite pred_label from 'df' into pred_label in 'train_set_sample'

test_set_total['pred_label'] = df_total['pred_label'].values
test_set_total
# Out:
#                                                  review  label  \
# 1549                   Very intrusive, so I turn it off      0
# 1036                             Alexa hardly came on..      0
# 2706  Great to play music throughout the house. Grea...      1
# 1311  LOVE love love this!  I have an echo, and seve...      1
# 2390  I would not recommend this to anyone. It won't...      0
# ...                                                 ...    ...
# 2621                                            Love it      1
# 618                             Extremely low in volume      0
# 1628  Echo Show is perfect for staging in the kitche...      1
# 1013  My  wife & I enjoy the ease of playing our mus...      1
# 3138  Este producto llegó y a la semana se quedó sin...      1
#
#                                           clean_reviews  pred_label
# 1549                      very intrusive so turn it off           0
# 1036                               alexa hardly came on           0
# 2706  great to play music throughout the house great...           1
# 1311  love love love this have an echo and several e...           1
# 2390  would not recommend this to anyone it won load...           0
# ...                                                 ...         ...
# 2621                                            love it           1
# 618                             extremely low in volume           0
# 1628  echo show is perfect for staging in the kitche...           1
# 1013  my wife enjoy the ease of playing our music th...           1
# 3138  este producto llegó la semana se quedó sin olo...           0
#
# [100 rows x 4 columns]

# %%
# Plotting confusion matrix on the predictions

from sklearn.metrics import confusion_matrix, accuracy_score

y_true = test_set_total["label"]
y_pred = test_set_total["pred_label"]

confusion_matrix(y_true, y_pred)
# Out:
# array([[48,  1],
#        [ 3, 48]])

# %%
accuracy_score(y_true, y_pred)
# Out:
# 0.96
